# %% [markdown]
# <a href="https://colab.research.google.com/github/3kutlu/PyCaret/blob/main/Regression_Health_Insurance_Cost_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem**: Developing an Automated Health Insurance Cost Prediction System

# %% [markdown]
# ## **Benefits of PyCaret**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# **Data Collection and Analysis**

# %%
insurance_data = pd.read_csv('insurance.csv')
insurance_data.head()
# Out:
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# ...

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.isnull().sum() #checking for missing values presence
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#statistical analysis of data
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
sns.set()
plt.figure(figsize=(6, 6))
age_data = insurance_data['age']
# Create histogram
sns.histplot(data=age_data, bins=10, kde=True, color='blue', label='Histogram')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x='sex', data=insurance_data)
plt.title('Sex Distribution')
plt.show()

# %%
sns.set()
plt.figure(figsize=(6, 6))
age_data = insurance_data['bmi']
# Create histogram
sns.histplot(data=age_data, bins=20, kde=True, color='blue', label='Histogram')
plt.title('Age Distribution')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x='smoker', data=insurance_data)
plt.title('Smoker')
plt.show()

# %%
#Charges Distribution
sns.set()
plt.figure(figsize=(6, 6))
age_data = insurance_data['charges']
# Create histogram
sns.histplot(data=age_data, bins=20, kde=True, color='blue', label='Histogram')
plt.title('Charges Distribution')
plt.xlabel('Charges')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# **Encoding Categorical Data**

# %%
insurance_data.replace({'sex':{'male':0, 'female':1}}, inplace = True)
insurance_data.replace({'smoker':{'yes':0, 'no':1}}, inplace = True)
insurance_data.replace({'region':{'southeast':0, 'southwest':1, 'northeast':2, 'northwest' : 3}}, inplace = True)

# %% [markdown]
# **Splitting Features and Target**

# %%
data = insurance_data.drop(columns='charges', axis = 1)
target = insurance_data['charges']

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       1
# 1      18    0  33.770         1       1       0
# 2      28    0  33.000         3       1       0
# 3      33    0  22.705         0       1       3
# 4      32    0  28.880         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       3
# 1334   18    1  31.920         0       1       2
# 1335   18    1  36.850         0       1       0
# 1336   21    1  25.800         0       1       1
# 1337   61    1  29.070         0       0       3
#
# [1338 rows x 6 columns]

# %%
target
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# **PyCaret**

# %%
from pycaret.regression import *

# %%
setup(data = data, target = target)
# Out:
# <style type="text/css">
# #T_b282e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b282e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b282e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b282e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b282e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b282e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b282e_row0_col1" class="data row0 col1" >5897</td>
#     </tr>
#     <tr>
#       <th id="T_b282e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b282e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b282e_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_b282e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# **This part is the golden part that makes PyCaret so important**

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6b015 th {
#   text-align: left;
# }
# ...
